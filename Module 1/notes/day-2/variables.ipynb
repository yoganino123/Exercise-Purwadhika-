# %%
nama = 'Fikri'
print(nama)
# Out:
# Fikri

# %%
nama
# Out:
# 'Fikri'

# %%
ikan = 'lele'

# %%
ikan
# Out:
# 'lele'

# %%
ikan = 'hiu'

# %%
ikan
# Out:
# 'hiu'

# %%
jumlah = 10
jumlah
# Out:
# 10

# %%
angka_pertama = 5
angka_kedua = '5'

# %%
angka_pertama + 3
# Out:
# 8

# %%
angka_kedua + '3'
# Out:
# '53'

# %%
angkaKetiga = 7

# %%
angkaKetiga
# Out:
# 7
