# %% [markdown]
# # Arithmetic Operation

# %%
# int
x1 = 5

# float
x2 = 7.7

# %%
# penjumlahan
x1 + x2
# Out:
# 12.7

# %%
# pengurangan
x2 - x1
# Out:
# 2.7

# %%
# perkalian
x1 * x2
# Out:
# 38.5

# %%
# pembagian
x2 / x1
# Out:
# 1.54

# %%
# pangkat
x1 ** 2
# Out:
# 25

# %%
# floor division
x1 // 2
# Out:
# 2

# %%
# modulus
x1 % 2
# Out:
# 1

# %% [markdown]
# # Assignment Operators

# %%
x1 = 4

# %%
x1 += 2
x1
# Out:
# 6

# %%
x1 -= 2
x1
# Out:
# 4

# %%
x1 *= 3
x1
# Out:
# 12

# %% [markdown]
# # Math Module

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil(4.2)
# Out:
# 5

# %%
math.floor(4.99991)
# Out:
# 4

# %%
math.fabs(-99.5)
# Out:
# 99.5

# %%
math.sqrt(49)
# Out:
# 7.0

# %% [markdown]
# # Casting

# %%
umur = '25'
umur
# Out:
# '25'

# %%
umur_int = int(umur)
umur_int
# Out:
# 25

# %%
umur_int + 3
# Out:
# 28

# %%
income = 70.9
income_int = int(income)

# %%
income_int
# Out:
# 70

# %%
income = '70.9'
income_float = float(income)
income_int = int(income_float)

# %%
income_float
# Out:
# 70.9

# %%
income_int
# Out:
# 70
